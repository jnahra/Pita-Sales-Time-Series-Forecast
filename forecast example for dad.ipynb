# %%
import pandas as pd

# %%
df = pd.read_csv('data/future_forecast.csv')

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date',inplace=True)

# %%
pd.set_option('display.max_rows', None)

# %%
df['2023-04-22':'2023-07-01'].plot();
